# %% [markdown]
# <a href="https://colab.research.google.com/github/ebenezerba/Udemycoursedataanalysis/blob/main/udemy_proj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Load the dataset
udemy = pd.read_csv("/content/udemy.csv")

# %%
udemy.head(300)
# Out:
#           id                                              title  \
# 0     762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1     937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2    1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3     648826         The Complete Financial Analyst Course 2020
# 4     637930  An Entire MBA in 1 Course:Award Winning Busine...
# ..       ...                                                ...
# 295  1444056  Six Sigma Yellow Belt Masterclass (includes a ...
# 296  1289030  Business Continuity Management System. ISO 22301.
# 297  2209946  Complete Tableau 2020 Training for Absolute Be...
# 298   408440              How to Win 97% of Your Options Trades
# 299  1358224                      Project Management Essentials
#
#                                                    url  is_paid  \
# 0                   /course/the-complete-sql-bootcamp/     True
# 1                                   /course/tableau10/     True
# ...

# %%
for col in udemy.columns:
    print(f"Unique values in column '{col}':")
    print(udemy[col].unique())
    print()
# Out:
# Unique values in column 'id':
# [ 762616  937678 1361790 ... 1964000 2769588 2801192]
#
# Unique values in column 'title':
# ['The Complete SQL Bootcamp 2020: Go from Zero to Hero'
#  'Tableau 2020 A-Z: Hands-On Tableau Training for Data Science'
#  'PMP Exam Prep Seminar -  PMBOK Guide 6' ...
#  'Leadership Development:Ready To Use Tools to lead Your Team'
#  'Business Efficiency: How To Increase Workplace Productivity'
#  'How to enter the US market?']
#
# Unique values in column 'url':
# ['/course/the-complete-sql-bootcamp/' '/course/tableau10/'
#  '/course/pmp-pmbok6-35-pdus/' ...
#  '/course/leadership-development-how-to-lead-your-team/'
#  '/course/business-efficiency-how-to-increase-workplace-productivity/'
#  '/course/how-to-enter-the-us-market/']
#
# Unique values in column 'is_paid':
# [ True]
#
# Unique values in column 'num_subscribers':
# [295509 209070 155282 ...    786   3289   1716]
#
# Unique values in column 'avg_rating':
# ...

# %%
udemy.describe()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Set the style of seaborn
sns.set(style="whitegrid")

# %%
# Distribution of course ratings
plt.figure(figsize=(10, 6))
sns.histplot(udemy['avg_rating'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Course Ratings on Udemy')
plt.xlabel('Average Rating')
plt.ylabel('Frequency')
plt.show()
